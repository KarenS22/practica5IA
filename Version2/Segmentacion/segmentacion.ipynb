# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

from ultralytics import YOLO

# Cargar modelo preentrenado (elige el que tú quieras)
model = YOLO('yolov8s-seg.pt')  # Ya es el más pequeño, pero si usaste s o m, cambia a n

# Entrenar con tu dataset
model.train(
    data='Dataset/data.yaml',
    epochs=150,
    imgsz=640,
    task='segment'
)
# Out:
# Ultralytics 8.3.169  Python-3.10.18 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...
